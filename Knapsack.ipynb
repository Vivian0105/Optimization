# %%
import mlrose
import numpy as np
import time
import matplotlib.pyplot as plt
import math

# %%
weights=[10,5,2,8,15]
values=[1,2,3,4,5]
max_weight_pct=0.6
fitness=mlrose.Knapsack(weights,values,max_weight_pct)

# %%
problem = mlrose.DiscreteOpt(length = 5, fitness_fn = fitness,
                             maximize = True, max_val = 6)

# %%
iteration=[10,100,1000,10000,100000,1000000]

# %%
schedule = mlrose.ExpDecay()
np.random.seed(2)
annealing_best_fitness=[]
time_start=time.clock()
for i in iteration:
    best_state, best_fitness = mlrose.simulated_annealing(problem, schedule = schedule,
                                                      max_attempts = 100, max_iters = i)
    annealing_best_fitness.append(best_fitness)
time_fit_annealing=time.clock()-time_start
print('The best state found is: ', best_state)
print('The fitness at the best state is: ', annealing_best_fitness)
print('Time needed is:', time_fit_annealing)
# Out:
# The best state found is:  [1 1 4 0 0]
# The fitness at the best state is:  [0.0, 14.0, 14.0, 21.0, 21.0, 15.0]
# Time needed is: 0.10116594706050819

# %%
np.random.seed(2)
genetic_best_fitness=[]
time_start=time.clock()
for i in iteration:
    best_state, best_fitness = mlrose.genetic_alg(problem,mutation_prob=0.1,max_attempts=100,max_iters=i)
    genetic_best_fitness.append(best_fitness)
time_fit_genetic=time.clock()-time_start
print('The best state found is: ', best_state)
print('The fitness at the best state is: ', genetic_best_fitness)
print('Time needed is:', time_fit_genetic)
# Out:
# The best state found is:  [0 1 5 1 0]
# The fitness at the best state is:  [20.0, 21.0, 21.0, 21.0, 21.0, 21.0]
# Time needed is: 9.31581825084686

# %%
np.random.seed(2)
hill_best_fitness=[]
time_start=time.clock()
for i in iteration:
    best_state, best_fitness = mlrose.random_hill_climb(problem,max_attempts=100,max_iters=i)
    hill_best_fitness.append(best_fitness)
time_fit_hill=time.clock()-time_start    
print('The best state found is: ', best_state)
print('The fitness at the best state is: ', hill_best_fitness)
print('Time needed is:', time_fit_hill)
# Out:
# The best state found is:  [4 4 2 1 5]
# The fitness at the best state is:  [0.0, 0.0, 0.0, 14.0, 0.0, 0.0]
# Time needed is: 0.024675584802025696

# %%
np.random.seed(2)
restarthill_best_fitness=[]
time_start=time.clock()
for i in iteration:
    best_state, best_fitness = mlrose.random_hill_climb(problem,max_attempts=100,max_iters=i,restarts=10)
    restarthill_best_fitness.append(best_fitness)
time_fit_rehill=time.clock()-time_start    
print('The best state found is: ', best_state)
print('The fitness at the best state is: ', restarthill_best_fitness)
print('Time needed is:', time_fit_rehill)
# Out:
# The best state found is:  [1 1 4 0 0]
# The fitness at the best state is:  [0.0, 11.0, 19.0, 0.0, 0.0, 15.0]
# Time needed is: 0.19993110115319723

# %%
np.random.seed(2)
mimic_best_fitness=[]
time_start=time.clock()
for i in iteration:
    best_state, best_fitness = mlrose.mimic(problem,pop_size=200,keep_pct=0.2,max_attempts=100,max_iters=i)
    mimic_best_fitness.append(best_fitness) 
time_fit_mimic=time.clock()-time_start      
print('The best state found is: ', best_state)
print('The fitness at the best state is: ',mimic_best_fitness)
print('Time needed is:', time_fit_mimic)
# Out:
# The best state found is:  [0 1 5 1 0]
# The fitness at the best state is:  [17.0, 20.0, 20.0, 18.0, 21.0, 21.0]
# Time needed is: 7.244334511804482

# %%
x=[math.log10(x) for x in iteration]
plt.plot(x,annealing_best_fitness,'r^--',x,genetic_best_fitness,'bo--',
         x,hill_best_fitness,'y^--',x,restarthill_best_fitness,'go--',x,mimic_best_fitness,'k^--')
plt.axis([0,7,-1,22])
plt.ylabel('Fitness')
plt.xlabel('log10(iteration)')
plt.title('Knapsack Problem')
plt.savefig('E:/Machine Learning/HW2/Knapsack.png')

# %%
schedule = mlrose.ExpDecay()
np.random.seed(2)
annealing_best_fitness2=[]
for i in iteration:
    best_state, best_fitness = mlrose.simulated_annealing(problem, schedule = schedule,
                                                      max_attempts = 100 , max_iters = i)
    annealing_best_fitness2.append(best_fitness)
print('The best state found is: ', best_state)
print('The fitness at the best state is: ', annealing_best_fitness2)
# Out:
# The best state found is:  [1 1 4 0 0]
# The fitness at the best state is:  [0.0, 14.0, 14.0, 21.0, 21.0, 15.0]

# %%
np.random.seed(2)
hill_best_fitness2=[]
for i in iteration:
    best_state, best_fitness = mlrose.random_hill_climb(problem,max_attempts=100,max_iters=i)
    hill_best_fitness2.append(best_fitness)  
print('The best state found is: ', best_state)
print('The fitness at the best state is: ', hill_best_fitness2)
# Out:
# The best state found is:  [4 4 2 1 5]
# The fitness at the best state is:  [0.0, 0.0, 0.0, 14.0, 0.0, 0.0]

# %%
np.random.seed(2)
restarthill_best_fitness2=[]
for i in iteration:
    best_state, best_fitness = mlrose.random_hill_climb(problem,max_attempts=100,max_iters=i,restarts=50)
    restarthill_best_fitness2.append(best_fitness)   
print('The best state found is: ', best_state)
print('The fitness at the best state is: ', restarthill_best_fitness2)
# Out:
# The best state found is:  [0 0 4 0 1]
# The fitness at the best state is:  [16.0, 20.0, 21.0, 18.0, 21.0, 17.0]

# %%
np.random.seed(2)
mimic_best_fitness2=[]
for i in iteration:
    best_state, best_fitness = mlrose.mimic(problem,pop_size=400,keep_pct=0.05,max_attempts=100,max_iters=i)
    mimic_best_fitness2.append(best_fitness)      
print('The best state found is: ', best_state)
print('The fitness at the best state is: ',mimic_best_fitness2)
# Out:
# The best state found is:  [0 1 5 1 0]
# The fitness at the best state is:  [19.0, 21.0, 19.0, 19.0, 20.0, 21.0]

# %%
np.random.seed(1)
genetic_best_fitness2=[]
for i in iteration:
    best_state, best_fitness = mlrose.genetic_alg(problem,mutation_prob=0.2,max_attempts=100,max_iters=i)
    genetic_best_fitness2.append(best_fitness)
print('The best state found is: ', best_state)
print('The fitness at the best state is: ', genetic_best_fitness2)
# Out:
# The best state found is:  [0 1 5 1 0]
# The fitness at the best state is:  [21.0, 21.0, 21.0, 21.0, 21.0, 21.0]

# %%
plt.plot(x,annealing_best_fitness2,'r^--',x,genetic_best_fitness2,'bo--',
         x,hill_best_fitness2,'y^--',x,restarthill_best_fitness2,'go--',x,mimic_best_fitness2,'k^--')
plt.axis([0,7,-1,22])
plt.ylabel('Fitness')
plt.xlabel('log10(iteration)')
plt.title('Knapsack Problem with Tuned Parameters')
plt.savefig('E:/Machine Learning/HW2/Knapsack_Better.png')

# %%
restarthill_best_fitness2=[[],[],[],[],[]]
restarts=[10,20,30,40,50]
for j in restarts:
    for i in iteration:    
        best_state, best_fitness = mlrose.random_hill_climb(problem,max_attempts=100,max_iters=i,restarts=j)
        restarthill_best_fitness2[int(j/10-1)].append(best_fitness)   
print('The best state found is: ', best_state)
print('The fitness at the best state is: ', restarthill_best_fitness2)
# Out:
# The best state found is:  [0 3 4 0 0]
# The fitness at the best state is:  [[0.0, 13.0, 0.0, 0.0, 18.0, 0.0], [0.0, 10.0, 19.0, 19.0, 21.0, 18.0], [15.0, 19.0, 21.0, 17.0, 20.0, 20.0], [20.0, 18.0, 21.0, 20.0, 21.0, 15.0], [13.0, 21.0, 19.0, 21.0, 20.0, 18.0]]

# %%
np.random.seed(2)
x=[math.log10(x) for x in iteration]
plt.plot(x,restarthill_best_fitness2[0],'0.9',x,restarthill_best_fitness2[1],'0.8',x,restarthill_best_fitness2[2],'0.7',x,restarthill_best_fitness2[3],'0.4',x,restarthill_best_fitness2[4],'0.1')
plt.axis([0,7,-1,22])
plt.ylabel('Fitness')
plt.xlabel('log10(iteration)')
plt.title('Knapsack Problem_hill climbing with different restart')
plt.savefig('E:/Machine Learning/HW2/Knapsack_hill.png')
